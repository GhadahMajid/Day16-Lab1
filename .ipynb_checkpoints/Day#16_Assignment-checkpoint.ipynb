# %%
# import warnings
# warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("Loan_Defaults.csv")
df.head()
# Out:
#    UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0    655269             53478       63558  86.54         67        22807
# 1    723482             55513       63163  89.45         67        22807
# 2    758529             65282       84320  79.93         78        23135
# 3    763449             46905       63896  76.58         78        17014
# 4    708663             51428       63896  86.08         78        17014
#
#    MANUFACTURER_ID  CURRENT_PINCODE_ID DATE_OF_BIRTH EMPLOYMENT_TYPE  \
# 0               45                1497    01-01-1974        Salaried
# 1               45                1497    20-05-1985   Self employed
# 2               86                2071    14-10-1995        Salaried
# 3               45                2070    01-06-1973   Self employed
# 4               45                2069    01-06-1972        Salaried
#
#   DISBURSAL_DATE  STATE_ID  EMPLOYEE_CODE_ID  MOBILENO_AVL_FLAG  AADHAR_FLAG  \
# ...

# %%
## Calculate Mean, Median, Mode, and Standard Deviation of the amount of Loan disbursed 
##in the column named disbursed_amount.

# %%
df['DISBURSED_AMOUNT'].describe()
# Out:
# count    112392.000000
# mean      56076.803269
# std       13123.697627
# min       11613.000000
# 25%       48849.000000
# 50%       55359.000000
# 75%       62147.000000
# max      940690.000000
# Name: DISBURSED_AMOUNT, dtype: float64

# %%
df.boxplot(column='DISBURSED_AMOUNT');

# %%
df['DISBURSED_AMOUNT'].mean()
# Out:
# 56076.80326891594

# %%
df['DISBURSED_AMOUNT'].median()
# Out:
# 55359.0

# %%
df['DISBURSED_AMOUNT'].mode()
# Out:
# 0    53303
# dtype: int64

# %%
df['DISBURSED_AMOUNT'].std()
# Out:
# 13123.697627449983

# %%
# Explain your findings for a value of your choice
df['DISBURSED_AMOUNT'].median()
# Out:
# 55359.0

# %% [markdown]
# #### As we can see the data in the amount of Loan disbursed column is widely spread (based on the boxplot and the std value) and we have few records where the amount of loan is huge (like 940690), so I believe using the median will give us a better statistical summary about the column data.

# %%
## Write a SQL query to calculate the mean of the variable disbursed_amount. Let the table be loan_defaults.
# These conditions applies to the query results:  
#for the salaried segment who have the time since their first loan been over 9 years

# --> EMPLOYMENT_TYPE = Salaried AND CREDIT_HISTORY_LENGTH > 9yrs ()

# Create a colum with number of months for CREDIT_HISTORY_LENGTH
y = df["CREDIT_HISTORY_LENGTH"].str.extract("(\d+)yrs", expand=False).astype(int)
m = df["CREDIT_HISTORY_LENGTH"].str.extract("(\d+)mon", expand=False).astype(int)
df["CREDIT_HISTORY_LENGTH_MONTHS"] = y * 12 + m
df.head()
# Out:
#    UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0    655269             53478       63558  86.54         67        22807
# 1    723482             55513       63163  89.45         67        22807
# 2    758529             65282       84320  79.93         78        23135
# 3    763449             46905       63896  76.58         78        17014
# 4    708663             51428       63896  86.08         78        17014
#
#    MANUFACTURER_ID  CURRENT_PINCODE_ID DATE_OF_BIRTH EMPLOYMENT_TYPE  \
# 0               45                1497    01-01-1974        Salaried
# 1               45                1497    20-05-1985   Self employed
# 2               86                2071    14-10-1995        Salaried
# 3               45                2070    01-06-1973   Self employed
# 4               45                2069    01-06-1972        Salaried
#
#   DISBURSAL_DATE  STATE_ID  EMPLOYEE_CODE_ID  MOBILENO_AVL_FLAG  AADHAR_FLAG  \
# ...

# %%
# pip install pandasql
from pandasql import sqldf

loan_defaults = sqldf('SELECT * FROM df WHERE EMPLOYMENT_TYPE == \'Salaried\' \
                                            AND CREDIT_HISTORY_LENGTH_MONTHS > 108')

# %%
loan_defaults.head()
# Out:
#    UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0    658270             46395       68612  69.96         74        22928
# 1    709207             39800       63794  63.96         20        23502
# 2    741979             61447       72428  86.98         63        16309
# 3    728574             38841       72524  55.15         48        15905
# 4    718257             31484       66053  48.45         48        15905
#
#    MANUFACTURER_ID  CURRENT_PINCODE_ID DATE_OF_BIRTH EMPLOYMENT_TYPE  \
# 0               86                2578    01-01-1975        Salaried
# 1               45                6186    10-12-1955        Salaried
# 2               45                7086    01-10-1965        Salaried
# 3               86                6261    01-01-1981        Salaried
# 4               86                6173    01-01-1974        Salaried
#
#   DISBURSAL_DATE  STATE_ID  EMPLOYEE_CODE_ID  MOBILENO_AVL_FLAG  AADHAR_FLAG  \
# ...

# %%
sqldf('SELECT AVG(DISBURSED_AMOUNT) AS Disbursed_amount_mean FROM loan_defaults ')
# Out:
#    Disbursed_amount_mean
# 0           55906.460897
